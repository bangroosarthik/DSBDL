# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import sklearn

# %%
#Load the dataSet using pd.read_csv -> for Comma separated values -> 
#for excel xlrd install first and then read_excel method use 
df=pd.read_csv("melb_data.csv")
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
#last 5 cols 
df.tail()
# Out:
#               Suburb        Address  Rooms Type      Price Method   SellerG  \
# 13575  Wheelers Hill   12 Strada Cr      4    h  1245000.0      S     Barry
# 13576   Williamstown  77 Merrett Dr      3    h  1031000.0     SP  Williams
# 13577   Williamstown    83 Power St      3    h  1170000.0      S     Raine
# 13578   Williamstown   96 Verdon St      4    h  2500000.0     PI   Sweeney
# 13579     Yarraville     6 Agnes St      4    h  1285000.0     SP   Village
#
#              Date  Distance  Postcode  ...  Bathroom  Car  Landsize  \
# 13575  26/08/2017      16.7    3150.0  ...       2.0  2.0     652.0
# 13576  26/08/2017       6.8    3016.0  ...       2.0  2.0     333.0
# 13577  26/08/2017       6.8    3016.0  ...       2.0  4.0     436.0
# 13578  26/08/2017       6.8    3016.0  ...       1.0  5.0     866.0
# 13579  26/08/2017       6.3    3013.0  ...       1.0  1.0     362.0
#
#        BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# ...

# %%
#(rows,cols)
df.shape
# Out:
# (13580, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
#it will provide you statistical details
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
#provide me the column names and their respective data types
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Car                62
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
df.Car.head()
# Out:
# 0    1.0
# 1    0.0
# 2    0.0
# 3    1.0
# 4    2.0
# Name: Car, dtype: float64

# %%
df.Car.isnull().sum()
# Out:
# 62

# %%
#drop Car column
new_df=df.drop('Car',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Regionname', 'Propertycount'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Suburb              0
# Address             0
# Rooms               0
# Type                0
# Price               0
# Method              0
# SellerG             0
# Date                0
# Distance            0
# Postcode            0
# Bedroom2            0
# Bathroom            0
# Landsize            0
# BuildingArea     6450
# YearBuilt        5375
# CouncilArea      1369
# Lattitude           0
# Longtitude          0
# Regionname          0
# Propertycount       0
# dtype: int64

# %%
#using dropna -> drop all nan values and created a new dataset
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df.Type.head()
# Out:
# 1    h
# 2    h
# 4    h
# 6    h
# 7    h
# Name: Type, dtype: object

# %%
df.Type=df.Type.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6196 entries, 1 to 12212
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         6196 non-null   object
#  1   Address        6196 non-null   object
#  2   Rooms          6196 non-null   int64
#  3   Type           6196 non-null   category
#  4   Price          6196 non-null   float64
#  5   Method         6196 non-null   object
#  6   SellerG        6196 non-null   object
#  7   Date           6196 non-null   object
#  8   Distance       6196 non-null   float64
#  9   Postcode       6196 non-null   float64
#  10  Bedroom2       6196 non-null   float64
#  11  Bathroom       6196 non-null   float64
#  12  Landsize       6196 non-null   float64
#  13  BuildingArea   6196 non-null   float64
#  14  YearBuilt      6196 non-null   float64
#  15  CouncilArea    6196 non-null   object
#  16  Lattitude      6196 non-null   float64
# ...

# %%
#converting date into Date dtype ->
df.Date
# Out:
# 1         4/02/2016
# 2         4/03/2017
# 4         4/06/2016
# 6         7/05/2016
# 7         8/10/2016
#             ...
# 12205    29/07/2017
# 12206    29/07/2017
# 12207    29/07/2017
# 12209    29/07/2017
# 12212    29/07/2017
# Name: Date, Length: 6196, dtype: object

# %%
#Converting Categorical Variable into Quantitative Variable

# %%
#1. using label encoder

# %%
#2. using one hot encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
#create object of LabelEncoder class

# %%
le=LabelEncoder()

# %%
df.Type=le.fit_transform(df['Type'])

# %%
df
# Out:
#              Suburb          Address  Rooms  Type      Price Method  \
# 1        Abbotsford  25 Bloomburg St      2     0  1035000.0      S
# 2        Abbotsford     5 Charles St      3     0  1465000.0     SP
# 4        Abbotsford      55a Park St      4     0  1600000.0     VB
# 6        Abbotsford     124 Yarra St      3     0  1876000.0      S
# 7        Abbotsford    98 Charles St      2     0  1636000.0      S
# ...             ...              ...    ...   ...        ...    ...
# 12205    Whittlesea    30 Sherwin St      3     0   601000.0      S
# 12206  Williamstown      75 Cecil St      3     0  1050000.0     VB
# 12207  Williamstown    2/29 Dover Rd      1     2   385000.0     SP
# 12209       Windsor  201/152 Peel St      2     2   560000.0     PI
# 12212    Yarraville  54 Pentland Pde      6     0  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  \
# 1             Biggin   4/02/2016       2.5    3067.0       2.0       1.0
# ...

# %%
#second method

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6196 entries, 1 to 12212
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         6196 non-null   object
#  1   Address        6196 non-null   object
#  2   Rooms          6196 non-null   int64
#  3   Type           6196 non-null   int32
#  4   Price          6196 non-null   float64
#  5   Method         6196 non-null   object
#  6   SellerG        6196 non-null   object
#  7   Date           6196 non-null   object
#  8   Distance       6196 non-null   float64
#  9   Postcode       6196 non-null   float64
#  10  Bedroom2       6196 non-null   float64
#  11  Bathroom       6196 non-null   float64
#  12  Landsize       6196 non-null   float64
#  13  BuildingArea   6196 non-null   float64
#  14  YearBuilt      6196 non-null   float64
#  15  CouncilArea    6196 non-null   object
#  16  Lattitude      6196 non-null   float64
# ...

# %%
df.Method
# Out:
# 1         S
# 2        SP
# 4        VB
# 6         S
# 7         S
#          ..
# 12205     S
# 12206    VB
# 12207    SP
# 12209    PI
# 12212    VB
# Name: Method, Length: 6196, dtype: object

# %%
df.Method=df.Method.astype('category')

# %%
df.Method.dtypes
# Out:
# CategoricalDtype(categories=['PI', 'S', 'SA', 'SP', 'VB'], ordered=False, categories_dtype=object)

# %%
#Converting Method into quantitative varibles pd.get_dummies(df,columns=[])

# %%
result=pd.get_dummies(df,columns=["Method"])

# %%
result
# Out:
#              Suburb          Address  Rooms  Type      Price        SellerG  \
# 1        Abbotsford  25 Bloomburg St      2     0  1035000.0         Biggin
# 2        Abbotsford     5 Charles St      3     0  1465000.0         Biggin
# 4        Abbotsford      55a Park St      4     0  1600000.0         Nelson
# 6        Abbotsford     124 Yarra St      3     0  1876000.0         Nelson
# 7        Abbotsford    98 Charles St      2     0  1636000.0         Nelson
# ...             ...              ...    ...   ...        ...            ...
# 12205    Whittlesea    30 Sherwin St      3     0   601000.0            Ray
# 12206  Williamstown      75 Cecil St      3     0  1050000.0       Williams
# 12207  Williamstown    2/29 Dover Rd      1     2   385000.0       Williams
# 12209       Windsor  201/152 Peel St      2     2   560000.0  hockingstuart
# 12212    Yarraville  54 Pentland Pde      6     0  2450000.0        Village
#
# ...
